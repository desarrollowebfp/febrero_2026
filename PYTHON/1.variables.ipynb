# %% [markdown]
# # Bienvenidos a Python

# %%
print("Hola")
# Out:
# Hola

# %% [markdown]
# ## Variables y tipos de dato

# %%
nombre = "Ana"  # string
edad = 34  # int
altura = 1.75  # float
es_estudiante = True  # boolean

print(
    "Me llamo "
    + nombre
    + ", tengo "
    + str(edad)
    + " años, y mido "
    + str(altura)
    + " m."
)
# Out:
# Me llamo Ana, tengo 34 años, y mido 1.75 m.
